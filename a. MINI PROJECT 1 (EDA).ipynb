# %%
#MINI PROJECT 1
#PERFORMING EDA ON A RANDOM DATASET

# %%
#for analysis and visualisation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#create a dataframe
df=pd.read_csv('/content/amazon_prime_titles.csv')
df
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %%
df.shape
# Out:
# (9668, 12)

# %%
df.size
# Out:
# 116016

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9668 non-null   object
#  1   type          9668 non-null   object
#  2   title         9668 non-null   object
#  3   director      7586 non-null   object
#  4   cast          8435 non-null   object
#  5   country       672 non-null    object
#  6   date_added    155 non-null    object
#  7   release_year  9668 non-null   int64
#  8   rating        9331 non-null   object
#  9   duration      9668 non-null   object
#  10  listed_in     9668 non-null   object
#  11  description   9668 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 906.5+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2082
# cast            1233
# country         8996
# date_added      9513
# release_year       0
# rating           337
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
df.nunique()
# Out:
# show_id         9668
# type               2
# title           9668
# director        5774
# cast            7927
# country           86
# date_added        84
# release_year     100
# rating            24
# duration         219
# listed_in        518
# description     9414
# dtype: int64

# %%
#1. no of types
type=df.type.unique()
print(type)
# Out:
# ['Movie' 'TV Show']

# %%
#2.streaming in which contries
country=df.country.unique()
print(country)
# Out:
# ['Canada' 'India' 'United States' 'United Kingdom' 'France' 'Spain' nan
#  'Italy' 'United Kingdom, France' 'United States, Italy'
#  'United States, India' 'United Kingdom, United States'
#  'United States, United Kingdom, Germany' 'Japan'
#  'China, United States, United Kingdom'
#  'Denmark, United Kingdom, Czech Republic, Netherlands'
#  'United States, Ireland' 'United States, United Kingdom, Canada'
#  'United Kingdom, United States, India' 'United Kingdom, India'
#  'United States, China' 'Canada, United States' 'United States, Thailand'
#  'Brazil, United States, India' 'Switzerland, India'
#  'United Kingdom, Canada, United States' 'Germany' 'Australia' 'Belgium'
#  'Chile, Argentina, United States' 'Mexico'
#  'Denmark, Sweden, United States' 'Netherlands'
#  'United States, United Kingdom' 'New Zealand' 'United States, Portugal'
#  'United States, France' 'Canada, United States, Brazil'
#  'France, United States' 'India, United States' 'India, Sweden'
# ...

# %%
len(country)
# Out:
# 87

# %%
len(type)
# Out:
# 2

# %%
#3.no of shows in each type
df.groupby(['type']).size()
# Out:
# type
# Movie      7814
# TV Show    1854
# dtype: int64

# %%
#4.visualisation for no. of shows in each type
gvis= df['type'].value_counts().head(15).plot(kind='barh',color=['lightblue','pink'],title='NO. OF SHOWS IN EACH TYPE')
display(gvis)
# Out:
# <Axes: title={'center': 'NO. OF SHOWS IN EACH TYPE'}>

# %%
#5.sorting data acc to type
s=df.sort_values('type')
s[['title','type']]
# Out:
#                                                 title     type
# 0                                 The Grand Seduction    Movie
# 6255                          Beyond The Purple Hills    Movie
# 6254                                          Big Sky    Movie
# 6253                              Blood and Chocolate    Movie
# 6251                     Bruce Lee: The Man, The Myth    Movie
# ...                                               ...      ...
# 3492  2019 Gold Series AVP New York City Open - Day 2  TV Show
# 3493  2019 Gold Series AVP New York City Open - Day 1  TV Show
# 1805                                    LOVE and LIES  TV Show
# 1814                                           Lorena  TV Show
# 2269                                      Half & Half  TV Show
#
# [9668 rows x 2 columns]

# %%
#6.no. of shows in each coountry
df.groupby(['country']).size()
# Out:
# country
# Afghanistan, France                          1
# Australia                                    4
# Australia, Colombia, United Kingdom          1
# Australia, United States, Germany            1
# Austria                                      1
#                                             ..
# United States, United Arab Emirates          1
# United States, United Kingdom                6
# United States, United Kingdom, Canada        1
# United States, United Kingdom, Germany       1
# United States, United Kingdom, Kazakhstan    1
# Length: 86, dtype: int64

# %%
#7.visualisation for no. of shows in each country
lvis= df['country'].value_counts().head(15).plot(kind='barh',color=['lightblue','pink'],title='NO. OF SHOWS IN EACH COUNTRY')
display(lvis)
# Out:
# <Axes: title={'center': 'NO. OF SHOWS IN EACH COUNTRY'}>

# %%
#8.sorting data acc to country
s=df.sort_values('country')
s[['title','country']]
# Out:
#                          title              country
# 5705               Kabullywood  Afghanistan, France
# 2180          Hotel Coolgardie            Australia
# 5430               The Tracker            Australia
# 7934  The Witch of Kings Cross            Australia
# 8119               Lost: MH370            Australia
# ...                        ...                  ...
# 9663       Pride Of The Bowery                  NaN
# 9664             Planet Patrol                  NaN
# 9665                   Outpost                  NaN
# 9666   Maradona: Blessed Dream                  NaN
# 9667               Harry Brown                  NaN
#
# [9668 rows x 2 columns]

# %%
#9.movies or shows released in 2021
l=df.sort_values('release_year',ascending=False)
release=l[['title','release_year']][:10]
release
# Out:
#                                    title  release_year
# 5438                          No Strings          2021
# 5543                      Deadly Passion          2021
# 6234  Go to School and Learn with Blippi          2021
# 6834     Where is Chicky? - Chapter Five          2021
# 8008                        Sema Thimiru          2021
# 7131                          Urban Envy          2021
# 8001                     Tappinchukoleru          2021
# 1241              Pungo - A Witch's Tale          2021
# 8937                 3 Pints and a Rabbi          2021
# 3331     Alien Conspiracy: They Are Here          2021

# %%
#10.visualisation of shows released in 2021
import plotly.express as px
fig_hist=px.bar(lengthy,x='title',y='release_year',title='released in 2021')
fig_hist.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#11.top 10 most rated shows
r=df.sort_values('rating',ascending=True)
r[['title','rating']][:10]
# Out:
#                      title rating
# 1     Take Care Good Night    13+
# 6063             Arjun Anu    13+
# 6054     Loving Miss Hatto    13+
# 6050           Punarjagran    13+
# 6047                Somnus    13+
# 2108      Infinity Chamber    13+
# 6036               Gracie!    13+
# 6033       Insaaf Ki Awaaz    13+
# 6066                 Worth    13+
# 6027  Nuvvunte Naa Jathaga    13+

# %%
#12.visualisation of top 10 most rated shows
import plotly.express as px
rating = r[['title','rating']][:10]
fig_hist=px.bar(rating,x='title',y='rating',title='top 10 most rated shows')
fig_hist.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#13.visualisation of duration count
sns.countplot(x=df['duration'])
fig = plt.gcf()
fig.set_size_inches(200,50)
plt.title('DURATION')
# Out:
# Text(0.5, 1.0, 'DURATION')
